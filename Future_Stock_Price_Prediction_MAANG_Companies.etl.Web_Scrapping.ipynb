# %%
import os
from google.colab import drive
drive.mount('/content/drive')
os.getcwd()
os.chdir('drive')
os.chdir('MyDrive')
os.chdir('Coursera Project')

# %%
# installing module for Yahoo Finance API
# !pip install yfinance

# %%
# Importing Necessary Libraries
import pandas as pd
import yfinance as yf
from datetime import datetime
from IPython.display import display

# %%
# Downloading data for the MAANG Companies
Company_names = ['Amazon', 'Apple', 'Google', 'Meta', 'Netflix']
company_dict = {}
company_dict["Amazon"]=yf.download('AMZN', period='max')
company_dict["Apple"]=yf.download('AAPL', period='max')
company_dict["Google"]=yf.download('GOOG', period='max')
company_dict["Meta"]=yf.download('META', period='max')
company_dict["Netflix"]=yf.download('NFLX', period='max')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
# Display Dataframes
for i in Company_names:
  print()
  print(f"Dataframe for {i} Company")
  display(company_dict[i])
  print()
# Out:
# Dataframe for Amazon Company
#                  Open       High        Low      Close  Adj Close      Volume
# Date
# 1997-05-15   0.121875   0.125000   0.096354   0.097917   0.097917  1443120000
# 1997-05-16   0.098438   0.098958   0.085417   0.086458   0.086458   294000000
# 1997-05-19   0.088021   0.088542   0.081250   0.085417   0.085417   122136000
# 1997-05-20   0.086458   0.087500   0.081771   0.081771   0.081771   109344000
# 1997-05-21   0.081771   0.082292   0.068750   0.071354   0.071354   377064000
# ...               ...        ...        ...        ...        ...         ...
# 2023-03-06  95.190002  96.550003  93.739998  93.750000  93.750000    52112400
# 2023-03-07  94.059998  95.089996  92.779999  93.550003  93.550003    49100700
# 2023-03-08  93.599998  94.169998  92.180000  93.919998  93.919998    44899100
# 2023-03-09  93.680000  96.209999  92.180000  92.250000  92.250000    56218700
# 2023-03-10  92.669998  93.570000  90.250000  90.730003  90.730003    69747500
#
# ...

# %%
# Describe Dataframes with null values
for i in Company_names:
  print()
  print(f"Description of data for {i} Company")
  display(company_dict[i].describe())
  print(f"Null values in the data for {i} Company")
  display(company_dict[i].isnull().sum(axis = 0))
  print()
# Out:
# Description of data for Amazon Company
#               Open         High          Low        Close    Adj Close  \
# count  6498.000000  6498.000000  6498.000000  6498.000000  6498.000000
# mean     31.425786    31.802941    31.010145    31.412629    31.412629
# std      48.031573    48.593805    47.401699    47.994680    47.994680
# min       0.070313     0.072396     0.065625     0.069792     0.069792
# 25%       1.995125     2.025000     1.957500     2.000125     2.000125
# 50%       6.399250     6.497000     6.304750     6.417000     6.417000
# 75%      38.288124    38.524001    38.026374    38.312751    38.312751
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  6.498000e+03
# mean   1.427673e+08
# std    1.402839e+08
# min    9.744000e+06
# 25%    6.901152e+07
# 50%    1.060610e+08
# 75%    1.609865e+08
# max    2.086584e+09
# Null values in the data for Amazon Company
# Open         0
# High         0
# Low          0
# ...

# %%
# Saving the Scarpped Data
for i in Company_names:
  company_dict[i].to_csv(i+'.csv', index=True)
